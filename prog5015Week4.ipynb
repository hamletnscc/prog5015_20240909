# %%
#Test if the board is working
import board
dir(board)
# Out:
# ['G0',
#  'G1',
#  'G2',
#  'G3',
#  'I2C',
#  'SCL',
#  'SDA',
#  '__blinka__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__repo__',
#  '__spec__',
#  '__version__',
#  'ap_board',
#  'board_id',
#  'detector',
#  'pin',
#  'sys']

# %%
import adafruit_ssd1306
import board
import busio
import digitalio
from PIL import Image, ImageDraw, ImageFont
import adafruit_ssd1306

# Define the Reset Pin
oled_reset = digitalio.DigitalInOut(board.G0)

# Change these
# to the right size for your display!
WIDTH = 128
HEIGHT = 32  # Change to 64 if needed
BORDER = 5

# Use for I2C.
i2c = board.I2C()  # uses board.SCL and board.SDA
# i2c = board.STEMMA_I2C()  # For using the built-in STEMMA QT connector on a microcontroller
oled = adafruit_ssd1306.SSD1306_I2C(WIDTH, HEIGHT, i2c, addr=0x3C, reset=oled_reset)

# Use for SPI
# spi = board.SPI()
# oled_cs = digitalio.DigitalInOut(board.D5)
# oled_dc = digitalio.DigitalInOut(board.D6)
# oled = adafruit_ssd1306.SSD1306_SPI(WIDTH, HEIGHT, spi, oled_dc, oled_reset, oled_cs)

# Clear display.
oled.fill(0)
oled.show()

# Create blank image for drawing.
# Make sure to create image with mode '1' for 1-bit color.
image = Image.new("1", (oled.width, oled.height))

# Get drawing object to draw on image.
draw = ImageDraw.Draw(image)

# Draw a white background
draw.rectangle((0, 0, oled.width, oled.height), outline=255, fill=255)

# Draw a smaller inner rectangle
draw.rectangle(
    (BORDER, BORDER, oled.width - BORDER - 1, oled.height - BORDER - 1),
    outline=0,
    fill=0,
)

# Load default font.
font = ImageFont.load_default()

# Draw Some Text
text = "Hello World!"
bbox = font.getbbox(text)
(font_width, font_height) = bbox[2] - bbox[0], bbox[3] - bbox[1]
draw.text(
    (oled.width // 2 - font_width // 2, oled.height // 2 - font_height // 2),
    text,
    font=font,
    fill=255,
)

# Display image
oled.image(image)
oled.show()

# %%
import adafruit_ssd1306
import board
import busio
import digitalio
from PIL import Image, ImageDraw, ImageFont
import adafruit_ssd1306
import time

# Define the Reset Pin
oled_reset = digitalio.DigitalInOut(board.G0)

# Change these
# to the right size for your display!
WIDTH = 128
HEIGHT = 32  # Change to 64 if needed
BORDER = 5

# Use for I2C.
i2c = board.I2C()  # uses board.SCL and board.SDA
# i2c = board.STEMMA_I2C()  # For using the built-in STEMMA QT connector on a microcontroller
oled = adafruit_ssd1306.SSD1306_I2C(WIDTH, HEIGHT, i2c, addr=0x3C, reset=oled_reset)

# Use for SPI
# spi = board.SPI()
# oled_cs = digitalio.DigitalInOut(board.D5)
# oled_dc = digitalio.DigitalInOut(board.D6)
# oled = adafruit_ssd1306.SSD1306_SPI(WIDTH, HEIGHT, spi, oled_dc, oled_reset, oled_cs)

# Clear display.
oled.fill(0)
oled.show()

# Create blank image for drawing.
# Make sure to create image with mode '1' for 1-bit color.
image = Image.new("1", (oled.width, oled.height))

# Get drawing object to draw on image.
draw = ImageDraw.Draw(image)

# Draw a white background
draw.rectangle((0, 0, oled.width, oled.height), outline=255, fill=255)

# Draw a smaller inner rectangle
draw.rectangle(
    (BORDER, BORDER, oled.width - BORDER - 1, oled.height - BORDER - 1),
    outline=0,
    fill=0,
)

# Load default font.
font = ImageFont.load_default()

# Draw Some Text
text = "Hello World!"
bbox = font.getbbox(text)
print(bbox)
(font_width, font_height) = bbox[2] - bbox[0], bbox[3] - bbox[1]
#(oled.width // 2 - font_width // 2, oled.height // 2 - font_height // 2)
x = -bbox[2]
while x < 128:
    draw.rectangle((0, 0, oled.width, oled.height), outline=0, fill=0)
    draw.text(
        (x, oled.height // 2 - font_height // 2),
        text,
        font=font,
        fill=255,
    )
    oled.image(image)
    oled.show()
    x = x+1
    if x == 127:
        x = -bbox[2]

'''
count = 1

while True:
    # Draw a white background
    draw.rectangle((0, 0, oled.width, oled.height), outline=255, fill=255)
    
    # Draw a smaller inner rectangle
    draw.rectangle((0, 0, count, oled.height), outline=255, fill=0)
    # Display image
    oled.image(image)
    oled.show()
    if count > oled.width:
        count = 0
    count+=1
    time.sleep(0.2)
'''
# Out:
# (0, 2, 58, 10)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[16], line 69
#      62 draw.text(
#      63     (x, oled.height // 2 - font_height // 2),
#      64     text,
#      65     font=font,
#      66     fill=255,
#      67 )
#      68 oled.image(image)
# ---> 69 oled.show()
#      70 x = x+1
#      71 if x == 127:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\adafruit_ssd1306.py:219, in _SSD1306.show(self)
#     217     self.write_cmd(0)
#     218     self.write_cmd(self.pages - 1)
# --> 219 self.write_framebuf()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\adafruit_ssd1306.py:287, in SSD1306_I2C.write_framebuf(self)
#     285 else:
#     286     with self.i2c_device:
# ...

# %%
#Demo on using time.monotonic() instead of time.sleep()

import time

counter = 0
startTime = time.monotonic() #Store the start time stamp using monotonic
while True:    
    if (time.monotonic() - startTime) >=1: #check if 1 second has passed
        counter = counter + 1
        startTime = time.monotonic() #update the startTime value for the next interval
        print("{count:5d}: {timestamp:.2f}".format(count=counter, timestamp=time.monotonic()))
